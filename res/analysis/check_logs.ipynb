# %%
import os
import numpy as np
from matplotlib import pyplot as plt

from collections import Counter

def plot_hist(k, name):
    plt.subplot(211)
    plt.hist(k[:, 0])
    plt.title('%s: 0 histogram' % (name,))

    plt.subplot(212)
    plt.hist(k[:, 1])
    plt.title('%s: 1 histogram' % (name,))
    plt.show()

# print(Counter((0 < k[:, 0]) & (k[:, 0] < 1)))
# print(Counter((0 < k[:, 1]) & (k[:, 1] < 1)))

# %%
fp = "/opt/logs/part4/2019_03_23/21_46_49_done/top/res/1_16.npy"
fp = r"/opt/logs/part4/2019_04_27/23_44_53/top/res"

k11 = np.load(os.path.join(fp, "17_11.npy"))
k13 = np.load(os.path.join(fp, "17_13.npy"))

plot_hist(k11, "17_11")
plot_hist(k13, "17_13")
